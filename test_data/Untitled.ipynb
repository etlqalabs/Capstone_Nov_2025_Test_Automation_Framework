# %%
import pandas as pd
from sqlalchemy import create_engine

mysql_conn = create_engine("mysql+pymysql://root:Admin%40143@localhost:3308/edw_retail_reporting")

# %%
df_actual = pd.read_sql("""select * from stag_sales""",mysql_conn)

# %%
df_expected = pd.read_csv("sales_data.csv")

# %%
df_expected['sales_id'].isin(df_actual['sales_id'])
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
#       ...
# 56     True
# 57     True
# 58     True
# 59     True
# 60     True
# Name: sales_id, Length: 61, dtype: bool

# %%
# expected data - actual data
df_extra_in_expected = df_expected[~df_expected.apply(tuple,axis=1).isin(df_actual.apply(tuple,axis=1))]

# %%
df_extra_in_expected.to_csv("extra_row_expected.csv")
