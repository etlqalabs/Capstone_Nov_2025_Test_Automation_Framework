# %%
import pandas as pd
from sqlalchemy import create_engine
mysql_conn = create_engine("mysql+pymysql://root:Admin%40143@localhost:3308/edw_retail_reporting")

# %%
df = pd.read_csv("sales_data.csv")

# %%
df.duplicated().any()
# Out:
# False

# %%
df['sales_id'].duplicated().any()
# Out:
# False

# %%
df['store_id'].isnull().values.any()
# Out:
# True

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().values.any()
# Out:
# True

# %%
foreign_df = pd.read_sql("""select * from fact_sales""",mysql_conn)
primary_df = pd.read_sql("""select * from stag_product""",mysql_conn)
df_not_matched = foreign_df[~foreign_df['product_id'].isin(primary_df['product_id'])]

# %%
df_not_matched.empty
# Out:
# False
